# %%
import fiona
shape = fiona.open("../files/shape files/RNC_PA_region.shp")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
for i in range(len(shape)):
    x=[]
    y=[]
    for coor in shape[i]['geometry']['coordinates'][0]:
        x.append(coor[0])
        y.append(coor[1])

    _ = plt.plot(x,y)

# %%
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon
point = Point(100.56,13.74)
polygon = Polygon(shape[0]['geometry']['coordinates'][0])

# %%
polygon.contains(point)
# Out:
# True

# %%
shape[0]
# Out:
# {'type': 'Feature',
#  'id': '0',
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[(100.624151, 13.805503),
#     (100.627708, 13.807042),
#     (100.627967, 13.807199),
#     (100.628452, 13.807152),
#     (100.628452, 13.80665),
#     (100.628614, 13.806163),
#     (100.628954, 13.804577),
#     (100.626382, 13.803917),
#     (100.626609, 13.803383),
#     (100.625881, 13.803226),
#     (100.625444, 13.803886),
#     (100.625234, 13.804215),
#     (100.624151, 13.805503)]]},
#  'properties': OrderedDict([('RNCNAME', '119')])}
